# %%
import pandas as pd
df = pd.read_csv("brown.csv")
corpus = df['tokenized_text'].tolist()

corpus[:5]
# Out:
# ['Furthermore , as an encouragement to revisionist thinking , it manifestly is fair to admit that any fraternity has a constitutional right to refuse to accept persons it dislikes .',
#  'The Unitarian clergy were an exclusive club of cultivated gentlemen -- as the term was then understood in the Back Bay -- and Parker was definitely not a gentleman , either in theology or in manners .',
#  'Ezra Stiles Gannett , an honorable representative of the sanhedrin , addressed himself frankly to the issue in 1845 , insisting that Parker should not be persecuted or calumniated and that in this republic no power to restrain him by force could exist .',
#  "Even so , Gannett judiciously argued , the Association could legitimately decide that Parker `` should not be encouraged nor assisted in diffusing his opinions by those who differ from him in regard to their correctness '' .",
#  'We today are not entitled to excoriate honest men who believed Parker to be downright pernicious and who barred their pulpits against his demand to poison the minds of their congregations .']

# %%
import re
import spacy

nlp = spacy.load("en_core_web_sm")


def clean_text(documents: list[str]):
    cleaned_docs = []
    for doc in documents:
        doc_text = re.sub(r"[^\w\s]", "", doc.lower())
        doc_nlp = nlp(doc_text)
        filtered_text = [token.text for token in doc_nlp if not token.is_stop and token.text.strip()]
        cleaned_docs.append(filtered_text)

    return cleaned_docs

cleaned_corpus = clean_text(corpus[:10000])
cleaned_corpus[:5]
# Out:
# [['furthermore',
#   'encouragement',
#   'revisionist',
#   'thinking',
#   'manifestly',
#   'fair',
#   'admit',
#   'fraternity',
#   'constitutional',
#   'right',
#   'refuse',
#   'accept',
#   'persons',
#   'dislikes'],
#  ['unitarian',
#   'clergy',
#   'exclusive',
#   'club',
#   'cultivated',
#   'gentlemen',
#   'term',
#   'understood',
#   'bay',
#   'parker',
#   'definitely',
#   'gentleman',
#   'theology',
#   'manners'],
#  ['ezra',
#   'stiles',
#   'gannett',
#   'honorable',
#   'representative',
#   'sanhedrin',
#   'addressed',
#   'frankly',
#   'issue',
#   '1845',
#   'insisting',
#   'parker',
#   'persecuted',
#   'calumniated',
#   'republic',
#   'power',
#   'restrain',
#   'force',
#   'exist'],
#  ['gannett',
#   'judiciously',
#   'argued',
#   'association',
#   'legitimately',
#   'decide',
#   'parker',
#   'encouraged',
#   'assisted',
#   'diffusing',
#   'opinions',
#   'differ',
#   'regard',
#   'correctness'],
#  ['today',
#   'entitled',
#   'excoriate',
#   'honest',
#   'men',
#   'believed',
#   'parker',
#   'downright',
#   'pernicious',
#   'barred',
#   'pulpits',
#   'demand',
#   'poison',
#   'minds',
#   'congregations']]

# %%
from collections import Counter

def build_vocab(corpus: list[str]):
    vocab = Counter(term for doc in corpus for term in doc)
    word_to_idx = {word: idx for idx, (word, _) in enumerate(vocab.items())}
    idx_to_word = {idx: word for idx, (word, _) in enumerate(vocab.items())}
    return word_to_idx, idx_to_word

word_to_idx, idx_to_word = build_vocab(cleaned_corpus)
print(word_to_idx)
print(idx_to_word)
print(len(word_to_idx))
# Out:
# {'furthermore': 0, 'encouragement': 1, 'revisionist': 2, 'thinking': 3, 'manifestly': 4, 'fair': 5, 'admit': 6, 'fraternity': 7, 'constitutional': 8, 'right': 9, 'refuse': 10, 'accept': 11, 'persons': 12, 'dislikes': 13, 'unitarian': 14, 'clergy': 15, 'exclusive': 16, 'club': 17, 'cultivated': 18, 'gentlemen': 19, 'term': 20, 'understood': 21, 'bay': 22, 'parker': 23, 'definitely': 24, 'gentleman': 25, 'theology': 26, 'manners': 27, 'ezra': 28, 'stiles': 29, 'gannett': 30, 'honorable': 31, 'representative': 32, 'sanhedrin': 33, 'addressed': 34, 'frankly': 35, 'issue': 36, '1845': 37, 'insisting': 38, 'persecuted': 39, 'calumniated': 40, 'republic': 41, 'power': 42, 'restrain': 43, 'force': 44, 'exist': 45, 'judiciously': 46, 'argued': 47, 'association': 48, 'legitimately': 49, 'decide': 50, 'encouraged': 51, 'assisted': 52, 'diffusing': 53, 'opinions': 54, 'differ': 55, 'regard': 56, 'correctness': 57, 'today': 58, 'entitled': 59, 'excoriate': 60, 'honest': 61, 'men': 62, 'believed': 63, 'downright': 64, 'pernicious': 65, 'barred': 66, 'pulpits': 67, 'demand': 68, 'poison': 69, 'minds': 70, 'congregations': 71, 'argue': 72, 'delicate': 73, 'matter': 74, 'justification': 75, 'existed': 76, 'returning': 77, 'public': 78, 'lecture': 79, 'church': 80, 'suppress': 81, 'let': 82, 'use': 83, 'sounding': 84, 'board': 85, 'propaganda': 86, 'turn': 87, 'come': 88, 'occupy': 89, 'finally': 90, 'clear': 91, 'day': 92, 'clergymen': 93, 'gannetts': 94, 'son': 95, 'explained': 96, 'biography': 97, 'father': 98, 'contended': 99, 'propriety': 100, 'claim': 101, 'title': 102, 'christians': 103, 'calvinist': 104, 'orthodoxy': 105, 'intellectual': 106, 'liberty': 107, 'meant': 108, 'follow': 109, 'free': 110, 'inquiry': 111, 'extreme': 112, 'proclaiming': 113, 'christianity': 114, 'natural': 115, 'religion': 116, 'grant': 117, 'modern': 118, 'unitarianism': 119, 'harvard': 120, 'divinity': 121, 'school': 122, 'recall': 123, 'humorous': 124, 'affection': 125, 'insults': 126, 'lavished': 127, 'received': 128, 'treatment': 129, 'invited': 130, 'betray': 131, 'uneasy': 132, 'conscience': 133, 'new': 134, 'england': 135, 'liberalism': 136, 'reminded': 137, 'dramatic': 138, 'confrontation': 139, 'january': 140, '23': 141, '1843': 142, 'defend': 143, 'privilege': 144, 'chandler': 145, 'robbins': 146, 'leave': 147, 'plead': 148, 'dr': 149, 'n': 150, 'l': 151, 'frothingham': 152, 'warrant': 153, 'stating': 154, 'difference': 155, 'trinitarians': 156, 'unitarians': 157, 'mr': 158, 'despite': 159, 'supposed': 160, 'conclusive': 161, 'assurances': 162, 'liberal': 163, 'heaves': 164, 'repeatedly': 165, 'sigh': 166, 'relief': 167, 'positive': 168, 'thanksgiving': 169, 'brought': 170, 'officially': 171, 'expel': 172, 'blot': 173, 'escutcheon': 174, 'remained': 175, 'indelible': 176, 'assemble': 177, 'honor': 178, 'parkers': 179, 'insurgence': 180, 'getting': 181, 'collective': 182, 'knees': 183, 'crying': 184, 'peccavi': 185, 'happily': 186, 'posterity': 187, 'boston': 188, 'actually': 189, 'command': 190, 'room': 191, 'came': 192, 'close': 193, 'comfort': 194, 'unforgivable': 195, 'brutality': 196, 'fortunately': 197, 'denomination': 198, 'attest': 199, 'cyrus': 200, 'bartol': 201, 'defended': 202, 'sincerity': 203, 'broke': 204, 'convulsions': 205, 'weeping': 206, 'rushed': 207, 'fellowship': 208, 'hall': 209, 'adjournment': 210, 'took': 211, 'warmly': 212, 'hand': 213, 'requested': 214, 'visit': 215, 'burly': 216, 'theodore': 217, 'burst': 218, 'tears': 219, 'near': 220, 'tragedy': 221, 'borders': 222, 'comedy': 223, 'enables': 224, 'tell': 225, 'story': 226, 'warming': 227, 'glow': 228, 'complacency': 229, 'thing': 230, 'inherent': 231, 'decency': 232, 'inherit': 233, 'triumph': 234, 'excommunicated': 235, 'extent': 236, 'ostracized': 237, 'reviled': 238, 'solace': 239, 'saying': 240, 'asked': 241, 'stratagems': 242, 'christian': 243, 'liberality': 244, 'laid': 245, 'rest': 246, 'university': 247, 'having': 248, 'abject': 249, 'penance': 250, 'rejection': 2 ...
# {0: 'furthermore', 1: 'encouragement', 2: 'revisionist', 3: 'thinking', 4: 'manifestly', 5: 'fair', 6: 'admit', 7: 'fraternity', 8: 'constitutional', 9: 'right', 10: 'refuse', 11: 'accept', 12: 'persons', 13: 'dislikes', 14: 'unitarian', 15: 'clergy', 16: 'exclusive', 17: 'club', 18: 'cultivated', 19: 'gentlemen', 20: 'term', 21: 'understood', 22: 'bay', 23: 'parker', 24: 'definitely', 25: 'gentleman', 26: 'theology', 27: 'manners', 28: 'ezra', 29: 'stiles', 30: 'gannett', 31: 'honorable', 32: 'representative', 33: 'sanhedrin', 34: 'addressed', 35: 'frankly', 36: 'issue', 37: '1845', 38: 'insisting', 39: 'persecuted', 40: 'calumniated', 41: 'republic', 42: 'power', 43: 'restrain', 44: 'force', 45: 'exist', 46: 'judiciously', 47: 'argued', 48: 'association', 49: 'legitimately', 50: 'decide', 51: 'encouraged', 52: 'assisted', 53: 'diffusing', 54: 'opinions', 55: 'differ', 56: 'regard', 57: 'correctness', 58: 'today', 59: 'entitled', 60: 'excoriate', 61: 'honest', 62: 'men', 63: 'believed', 64: 'downright', 65: 'pernicious', 66: 'barred', 67: 'pulpits', 68: 'demand', 69: 'poison', 70: 'minds', 71: 'congregations', 72: 'argue', 73: 'delicate', 74: 'matter', 75: 'justification', 76: 'existed', 77: 'returning', 78: 'public', 79: 'lecture', 80: 'church', 81: 'suppress', 82: 'let', 83: 'use', 84: 'sounding', 85: 'board', 86: 'propaganda', 87: 'turn', 88: 'come', 89: 'occupy', 90: 'finally', 91: 'clear', 92: 'day', 93: 'clergymen', 94: 'gannetts', 95: 'son', 96: 'explained', 97: 'biography', 98: 'father', 99: 'contended', 100: 'propriety', 101: 'claim', 102: 'title', 103: 'christians', 104: 'calvinist', 105: 'orthodoxy', 106: 'intellectual', 107: 'liberty', 108: 'meant', 109: 'follow', 110: 'free', 111: 'inquiry', 112: 'extreme', 113: 'proclaiming', 114: 'christianity', 115: 'natural', 116: 'religion', 117: 'grant', 118: 'modern', 119: 'unitarianism', 120: 'harvard', 121: 'divinity', 122: 'school', 123: 'recall', 124: 'humorous', 125: 'affection', 126: 'insults', 127: 'lavished', 128: 'received', 129: 'treatment', 130: 'invited', 131: 'betray', 132: 'uneasy', 133: 'conscience', 134: 'new', 135: 'england', 136: 'liberalism', 137: 'reminded', 138: 'dramatic', 139: 'confrontation', 140: 'january', 141: '23', 142: '1843', 143: 'defend', 144: 'privilege', 145: 'chandler', 146: 'robbins', 147: 'leave', 148: 'plead', 149: 'dr', 150: 'n', 151: 'l', 152: 'frothingham', 153: 'warrant', 154: 'stating', 155: 'difference', 156: 'trinitarians', 157: 'unitarians', 158: 'mr', 159: 'despite', 160: 'supposed', 161: 'conclusive', 162: 'assurances', 163: 'liberal', 164: 'heaves', 165: 'repeatedly', 166: 'sigh', 167: 'relief', 168: 'positive', 169: 'thanksgiving', 170: 'brought', 171: 'officially', 172: 'expel', 173: 'blot', 174: 'escutcheon', 175: 'remained', 176: 'indelible', 177: 'assemble', 178: 'honor', 179: 'parkers', 180: 'insurgence', 181: 'getting', 182: 'collective', 183: 'knees', 184: 'crying', 185: 'peccavi', 186: 'happily', 187: 'posterity', 188: 'boston', 189: 'actually', 190: 'command', 191: 'room', 192: 'came', 193: 'close', 194: 'comfort', 195: 'unforgivable', 196: 'brutality', 197: 'fortunately', 198: 'denomination', 199: 'attest', 200: 'cyrus', 201: 'bartol', 202: 'defended', 203: 'sincerity', 204: 'broke', 205: 'convulsions', 206: 'weeping', 207: 'rushed', 208: 'fellowship', 209: 'hall', 210: 'adjournment', 211: 'took', 212: 'warmly', 213: 'hand', 214: 'requested', 215: 'visit', 216: 'burly', 217: 'theodore', 218: 'burst', 219: 'tears', 220: 'near', 221: 'tragedy', 222: 'borders', 223: 'comedy', 224: 'enables', 225: 'tell', 226: 'story', 227: 'warming', 228: 'glow', 229: 'complacency', 230: 'thing', 231: 'inherent', 232: 'decency', 233: 'inherit', 234: 'triumph', 235: 'excommunicated', 236: 'extent', 237: 'ostracized', 238: 'reviled', 239: 'solace', 240: 'saying', 241: 'asked', 242: 'stratagems', 243: 'christian', 244: 'liberality', 245: 'laid', 246: 'rest', 247: 'university', 248: 'having', 249: 'abject', 250: 'penance', 251: 'rejectio ...
# 18516

# %%
def create_skipgram_pairs(corpus: list[str], window_size=2):
    """
    Generate context-target pairs for Skip-gram model training from a sequence of words.
    
    Args:
        sequence (list): A list of words (e.g., tokenized sentence or text).
        window_size (int): The number of words to consider as context on either side of the target word.
                           Default is 2 (looks 2 words before and after).
    
    Returns:
        list: A list of tuples, where each tuple is (target_word, context_word).
              The target word is the word being predicted, and the context word is one of its surrounding words.
    
    Example:
        >>> sequence = ['the', 'quick', 'brown', 'fox', 'jumps']
        >>> create_skipgram_pairs(sequence, window_size=2)
        [('the', 'quick'), ('the', 'brown'), ('quick', 'the'), ('quick', 'brown'),
         ('quick', 'fox'), ('brown', 'the'), ('brown', 'quick'), ('brown', 'fox'),
         ('brown', 'jumps'), ('fox', 'quick'), ('fox', 'brown'), ('fox', 'jumps'),
         ('jumps', 'brown'), ('jumps', 'fox')]
    """
    # Initialize an empty list to store the context-target pairs
    pairs = []
    
    # Iterate over each word in the sequence as the target word
    for document in corpus:
        for target_idx in range(len(document)):
            target_word = document[target_idx]
            
            # Define the window boundaries
            # Start: maximum of 0 (start of document) and target_idx - window_size
            # End: minimum of document length and target_idx + window_size + 1
            start_idx = max(0, target_idx - window_size)
            end_idx = min(len(document), target_idx + window_size + 1)
            
            # Generate pairs with context words within the window
            for context_idx in range(start_idx, end_idx):
                # Skip the target word itself (no self-pairing)
                if context_idx != target_idx:
                    context_word = document[context_idx]
                    # Add the (target, context) pair to the list
                    pairs.append((target_word, context_word))
    
    return pairs

pairs = create_skipgram_pairs(cleaned_corpus[:3], window_size=2)
pairs
# Out:
# [('furthermore', 'encouragement'),
#  ('furthermore', 'revisionist'),
#  ('encouragement', 'furthermore'),
#  ('encouragement', 'revisionist'),
#  ('encouragement', 'thinking'),
#  ('revisionist', 'furthermore'),
#  ('revisionist', 'encouragement'),
#  ('revisionist', 'thinking'),
#  ('revisionist', 'manifestly'),
#  ('thinking', 'encouragement'),
#  ('thinking', 'revisionist'),
#  ('thinking', 'manifestly'),
#  ('thinking', 'fair'),
#  ('manifestly', 'revisionist'),
#  ('manifestly', 'thinking'),
#  ('manifestly', 'fair'),
#  ('manifestly', 'admit'),
#  ('fair', 'thinking'),
#  ('fair', 'manifestly'),
#  ('fair', 'admit'),
#  ('fair', 'fraternity'),
#  ('admit', 'manifestly'),
#  ('admit', 'fair'),
#  ('admit', 'fraternity'),
#  ('admit', 'constitutional'),
#  ('fraternity', 'fair'),
#  ('fraternity', 'admit'),
#  ('fraternity', 'constitutional'),
#  ('fraternity', 'right'),
#  ('constitutional', 'admit'),
#  ('constitutional', 'fraternity'),
#  ('constitutional', 'right'),
#  ('constitutional', 'refuse'),
#  ('right', 'fraternity'),
#  ('right', 'constitutional'),
#  ('right', 'refuse'),
#  ('right', 'accept'),
#  ('refuse', 'constitutional'),
#  ('refuse', 'right'),
#  ('refuse', 'accept'),
#  ('refuse', 'persons'),
#  ('accept', 'right'),
#  ('accept', 'refuse'),
#  ('accept', 'persons'),
#  ('accept', 'dislikes'),
#  ('persons', 'refuse'),
#  ('persons', 'accept'),
#  ('persons', 'dislikes'),
#  ('dislikes', 'accept'),
#  ('dislikes', 'persons'),
#  ('unitarian', 'clergy'),
#  ('unitarian', 'exclusive'),
#  ('clergy', 'unitarian'),
#  ('clergy', 'exclusive'),
#  ('clergy', 'club'),
#  ('exclusive', 'unitarian'),
#  ('exclusive', 'clergy'),
#  ('exclusive', 'club'),
#  ('exclusive', 'cultivated'),
#  ('club', 'clergy'),
#  ('club', 'exclusive'),
#  ('club', 'cultivated'),
#  ('club', 'gentlemen'),
#  ('cultivated', 'exclusive'),
#  ('cultivated', 'club'),
#  ('cultivated', 'gentlemen'),
#  ('cultivated', 'term'),
#  ('gentlemen', 'club'),
#  ('gentlemen', 'cultivated'),
#  ('gentlemen', 'term'),
#  ('gentlemen', 'understood'),
#  ('term', 'cultivated'),
#  ('term', 'gentlemen'),
#  ('term', 'understood'),
#  ('term', 'bay'),
#  ('understood', 'gentlemen'),
#  ('understood', 'term'),
#  ('understood', 'bay'),
#  ('understood', 'parker'),
#  ('bay', 'term'),
#  ('bay', 'understood'),
#  ('bay', 'parker'),
#  ('bay', 'definitely'),
#  ('parker', 'understood'),
#  ('parker', 'bay'),
#  ('parker', 'definitely'),
#  ('parker', 'gentleman'),
#  ('definitely', 'bay'),
#  ('definitely', 'parker'),
#  ('definitely', 'gentleman'),
#  ('definitely', 'theology'),
#  ('gentleman', 'parker'),
#  ('gentleman', 'definitely'),
#  ('gentleman', 'theology'),
#  ('gentleman', 'manners'),
#  ('theology', 'definitely'),
#  ('theology', 'gentleman'),
#  ('theology', 'manners'),
#  ('manners', 'gentleman'),
#  ('manners', 'theology'),
#  ('ezra', 'stiles'),
#  ('ezra', 'gannett'),
#  ('stiles', 'ezra'),
#  ('stiles', 'gannett'),
#  ('stiles', 'honorable'),
#  ('gannett', 'ezra'),
#  ('gannett', 'stiles'),
#  ('gannett', 'honorable'),
#  ('gannett', 'representative'),
#  ('honorable', 'stiles'),
#  ('honorable', 'gannett'),
#  ('honorable', 'representative'),
#  ('honorable', 'sanhedrin'),
#  ('representative', 'gannett'),
#  ('representative', 'honorable'),
#  ('representative', 'sanhedrin'),
#  ('representative', 'addressed'),
#  ('sanhedrin', 'honorable'),
#  ('sanhedrin', 'representative'),
#  ('sanhedrin', 'addressed'),
#  ('sanhedrin', 'frankly'),
#  ('addressed', 'representative'),
#  ('addressed', 'sanhedrin'),
#  ('addressed', 'frankly'),
#  ('addressed', 'issue'),
#  ('frankly', 'sanhedrin'),
#  ('frankly', 'addressed'),
#  ('frankly', 'issue'),
#  ('frankly', '1845'),
#  ('issue', 'addressed'),
#  ('issue', 'frankly'),
#  ('issue', '1845'),
#  ('issue', 'insisting'),
#  ('1845', 'frankly'),
#  ('1845', 'issue'),
#  ('1845', 'insisting'),
#  ('1845', 'parker'),
#  ('insisting', 'issue'),
#  ('insisting', '1845'),
#  ('insisting', 'parker'),
#  ('insisting', 'persecuted'),
#  ('parker', '1845'),
#  ('parker', 'insisting'),
#  ('parker', 'persecuted'),
#  ('parker', 'calumniated'),
#  ('persecuted', 'insisting'),
#  ('persecuted', 'parker'),
#  ('persecuted', 'calumniated'),
#  ('persecuted', 'republic'),
#  ('calumniated', 'parker'),
#  ('calumniated', 'persecuted'),
#  ('calumniated', 'republic'),
#  ('calumniated', 'power'),
#  ('republic', 'persecuted'),
#  ('republic', 'calumniated'),
#  ('republic', 'power'),
#  ('republic', 'restrain'),
#  ('power', 'calumniated'),
#  ('power', 'republic'),
#  ('power', 'restrain'),
#  ('power', 'force'),
#  ('restrain', 'republic'),
#  ('restrain', 'power'),
#  ('restrain', 'force'),
#  ('restrain', 'exist'),
#  ('force', 'power'),
#  ('force', 'restrain'),
#  ('force', 'exist'),
#  ('exist', 'restrain'),
#  ('exist', 'force')]

# %%
def encode_pairs(pairs: list[str], word_to_idx: dict):
    encoded_pairs = []
    for context, target in pairs:
        context_idx = word_to_idx[context]
        target_idx = word_to_idx[target]
        encoded_pairs.append((context_idx, target_idx))

    return encoded_pairs

encoded_pairs = encode_pairs(pairs, word_to_idx)
encoded_pairs[:5]
# Out:
# [(0, 1), (0, 2), (1, 0), (1, 2), (1, 3)]
